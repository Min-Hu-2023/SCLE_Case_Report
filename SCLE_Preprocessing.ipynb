# %%
from spatialdata_io import xenium

SCLE_1_xenium = xenium("irAE-SCLE1")
SCLE_2_xenium = xenium("irAE-SCLE2")

SCLE_3_xenium = xenium("SCLE1")
SCLE_4_xenium = xenium("SCLE2")
SCLE_5_xenium = xenium("SCLE3")

normal_1_xenium = xenium("NS1")
normal_2_xenium = xenium("NS2")
normal_3_xenium = xenium("NS3")
normal_4_xenium = xenium("NS4")

SCLE_1_xenium.write("SCLE_1.zarr",overwrite=True)
SCLE_2_xenium.write("SCLE_2.zarr",overwrite=True)

SCLE_3_xenium.write("SCLE_3.zarr",overwrite=True)
SCLE_4_xenium.write("SCLE_4.zarr",overwrite=True)
SCLE_5_xenium.write("SCLE_5.zarr",overwrite=True)

normal_1_xenium.write("Normal_1.zarr",overwrite=True)
normal_2_xenium.write("Normal_2.zarr",overwrite=True)
normal_3_xenium.write("Normal_3.zarr",overwrite=True)
normal_4_xenium.write("Normal_4.zarr",overwrite=True)
